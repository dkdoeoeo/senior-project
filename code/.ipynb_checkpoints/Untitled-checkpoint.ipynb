# %%
import re
from itertools import chain

with open('E:/專題/data/2022/scc game/scc20220101-1.txt', 'r', encoding='utf-8') as file:
    content = file.read()
    conlist = re.split(r'[<>]', content)
    conlist = [s for s in conlist if s]
    del conlist[1]
    
    for item in conlist:
        
    print(conlist)
# Out:
# ['mjloggm ver="2.3"', 'GO type="169" lobby="0"/', 'UN n0="%7A%65%52%6F" n1="%E3%81%88%E3%81%84%E3%81%BF" n2="%E3%81%A8%E3%81%A3%E3%81%A8%E3%83%BC" n3="%E3%81%A6%E3%82%8B%E5%9D%8A%E4%B8%BB" dan="17,16,16,16" rate="2157.83,2125.37,2052.60,2039.94" sx="M,F,M,F"/', 'TAIKYOKU oya="0"/', 'INIT seed="0,0,0,2,2,13" ten="250,250,250,250" oya="0" hai0="99,126,12,104,122,92,114,18,55,93,84,28,37" hai1="35,127,5,43,98,68,53,48,34,132,129,75,42" hai2="0,40,103,74,113,1,107,124,130,112,10,60,95" hai3="71,57,106,52,128,32,105,38,78,58,86,70,54"/', 'T46/', 'D114/', 'U111/', 'E68/', 'V15/', 'F74/', 'W89/', 'G38/', 'T80/', 'D122/', 'U67/', 'E67/', 'V101/', 'F107/', 'W83/', 'G32/', 'T22/', 'D126/', 'U76/', 'E5/', 'V117/', 'F124/', 'W39/', 'G39/', 'T108/', 'D108/', 'U23/', 'E76/', 'V8/', 'F40/', 'W64/', 'G128/', 'T110/', 'D110/', 'U131/', 'E75/', 'V119/', 'F95/', 'W134/', 'G134/', 'T2/', 'D2/', 'U77/', 'E77/', 'V100/', 'F60/', 'W121/', 'G121/', 'T29/', 'D104/', 'U20/', 'E98/', 'V97/', 'F97/', 'W72/', 'G
# ...
